# %% [markdown]
# # Machine Learning for Free Weight Exercises
# *By Morgan Wallace* | morgan.m.wallace@gmail.com
#
# ##### Table of Contents
# 1. Import libraries and dataset
# 2. Data cleaning
# 3. Function declaration
# 4. Visualization, Exploration, and Observation

# %% [markdown]
# ----
# ### Import Libraries and Fetch Pickled Data

# %%
from __future__ import division

# import saved_data
import saved_data

import pickle
import sklearn
from sklearn import datasets, svm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pylab as pl

#put plots in ipython notebook, inline.
# %matplotlib inline

# %%
try:
    import mpld3
    from mpld3 import enable_notebook
    from mpld3 import plugins
    enable_notebook()
except Exception as e:
    print "Attempt to import and enable mpld3 failed", e

# %%
# what would seaborn do?
try:
    import seaborn as sns
except Exception as e:
    print "Attempt to import and enable seaborn failed", e

# %%
dataset=pickle.load(open('all_samples.p','rb'))
# print dataset[1]

# %% [markdown]
# ### Data cleaning using Pandas
#
# * Set column labels in data frame
# * Eliminate erroneous data

# %%
df=pd.DataFrame(dataset)
df.columns=saved_data.get_all(get_columns_only=True)

#get rid of first data point because it has erroneous data
df=df[df['t (sec)'] >0.01]

# %%
# give each set an id for iteration through sets
set_id=0
def check_time(time):
    global set_id
    if time<.2:
        set_id+=1
    return set_id
df['set_id'] = df['t (sec)'].apply(check_time)

# %%
# clear all the magnetometer error numbers (Really high numbers e.g. greater than 2000)
last_mag=0
def fix_mag(sample):
    global last_mag
    if abs(sample)>2000: #Magnetometer readings should be less than 2000 typically
        sample=last_mag
    else: last_mag=sample
    return sample

magnetometer_column=df.columns[10:13]
print magnetometer_column
for col in magnetometer_column:
    df[col] = df[col].apply(fix_mag)
# Out:
# Index([u'magnet_x', u'magnet_y', u'magnet_z'], dtype='object')

# %%
# This is how the data looks
df.head()
# Out:
#      User exerciseType  rep_count   t (sec)  acc_x  acc_y  acc_z  gyro_x  \
# 1  Morgan  bicep curls          0  0.164060  -0.04   0.90  -0.20     227
# 2  Morgan  bicep curls          0  0.242544  -0.05   0.90  -0.22     425
# 3  Morgan  bicep curls          0  0.374866  -0.08   0.90  -0.24    1485
# 4  Morgan  bicep curls          0  0.541655  -0.10   0.89  -0.25    2026
# 5  Morgan  bicep curls          0  0.642408  -0.24   0.90  -0.31    4959
#
#    gyro_y  gyro_z  magnet_x  magnet_y  magnet_z  set_id
# 1     281     -80     80.96   -201.48    224.48       1
# 2      -1    -443     80.04   -199.64    227.24       1
# 3    -190   -1723     88.32   -202.40    229.08       1
# 4    -799   -2590    103.96   -198.72    240.12       1
# 5   -3937   -8597    149.04   -194.12    262.20       1
#
# [5 rows x 14 columns]

# %%
df.describe()
# Out:
#        rep_count      t (sec)        acc_x        acc_y        acc_z  \
# count       7895  7895.000000  7895.000000  7895.000000  7895.000000
# mean           0    12.628657     0.138447     0.058101    -0.174760
# std            0     7.264680     0.510933     0.839318     0.279264
# min            0     0.156011    -1.130000    -1.900000    -1.200000
# 25%            0     6.343901    -0.260000    -0.880000    -0.320000
# 50%            0    12.644865     0.220000     0.410000    -0.200000
# 75%            0    18.944457     0.450000     0.840000    -0.050000
# max            0    25.153754     1.780000     1.460000     1.720000
#
#              gyro_x        gyro_y        gyro_z     magnet_x     magnet_y  \
# count   7895.000000   7895.000000   7895.000000  7895.000000  7895.000000
# mean    1032.109943    163.562381     41.588980    73.482189   289.198125
# std     8356.901187   5802.444287   9470.049539   286.979482   370.285116
# min   -32768.000000 -32752.000000 -32672.000000  -692.760000  -294.400000
# 25%    -2093.000000  -1417.000000  -4069.500000  -153.640000   -40.480000
# 50%      146.000000    218.000000    -15.000000    48.760000   258.520000
# 75%     3153.000000   2026.500000   4937.500000   222.640000   622.840000
# max    32752.000000  32752.000000  32752.000000   745.200000   944.840000
#
#           magnet_z       set_id
# count  7895.000000  7895.000000
# mean    -19.992375    19.981887
# std     212.342969    11.244301
# min    -581.440000     1.000000
# 25%    -165.600000    10.000000
# 50%     -45.080000    20.000000
# 75%      80.040000    30.000000
# max     758.080000    39.000000
#
# [8 rows x 12 columns]

# %% [markdown]
# ###Define functions:
# * peak detection
# * plotting

# %%
# Attribution: https://gist.github.com/schlady/1576079

def peakdetect(y_axis, x_axis = None, lookahead = 500, delta = 0):
    """
    Converted from/based on a MATLAB script at http://billauer.co.il/peakdet.html
    
    Algorithm for detecting local maximas and minmias in a signal.
    Discovers peaks by searching for values which are surrounded by lower
    or larger values for maximas and minimas respectively
    
    keyword arguments:
    y_axis -- A list containg the signal over which to find peaks
    x_axis -- A x-axis whose values correspond to the 'y_axis' list and is used
        in the return to specify the postion of the peaks. If omitted the index
        of the y_axis is used. (default: None)
    lookahead -- (optional) distance to look ahead from a peak candidate to
        determine if it is the actual peak (default: 500) 
        '(sample / period) / f' where '4 >= f >= 1.25' might be a good value
    delta -- (optional) this specifies a minimum difference between a peak and
        the following points, before a peak may be considered a peak. Useful
        to hinder the algorithm from picking up false peaks towards to end of
        the signal. To work well delta should be set to 'delta >= RMSnoise * 5'.
        (default: 0)
            Delta function causes a 20% decrease in speed, when omitted
            Correctly used it can double the speed of the algorithm
    
    return -- two lists [maxtab, mintab] containing the positive and negative
        peaks respectively. Each cell of the lists contains a tupple of:
        (position, peak_value) 
        to get the average peak value do 'np.mean(maxtab, 0)[1]' on the results
    """
    maxtab = []
    mintab = []
    dump = []   #Used to pop the first hit which always if false
       
    length = len(y_axis)
    if x_axis is None:
        x_axis = range(length)
    
    #perform some checks
    if length != len(x_axis):
        raise ValueError, "Input vectors y_axis and x_axis must have same length"
    if lookahead < 1:
        raise ValueError, "Lookahead must be above '1' in value"
    if not (np.isscalar(delta) and delta >= 0):
        raise ValueError, "delta must be a positive number"
    
    #needs to be a numpy array
    y_axis = np.asarray(y_axis)
    
    #maxima and minima candidates are temporarily stored in
    #mx and mn respectively
    mn, mx = np.Inf, -np.Inf
    
    #Only detect peak if there is 'lookahead' amount of points after it
    for index, (x, y) in enumerate(zip(x_axis[:-lookahead], y_axis[:-lookahead])):
        if y > mx:
            mx = y
            mxpos = x
        if y < mn:
            mn = y
            mnpos = x
        
        ####look for max####
        if y < mx-delta and mx != np.Inf:
            #Maxima peak candidate found
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].max() < mx:
                maxtab.append((mxpos, mx))
                dump.append(True)
                #set algorithm to only find minima now
                mx = np.Inf
                mn = np.Inf
            ## Morgan's addition
            
        
        ####look for min####
        if y > mn+delta and mn != -np.Inf:
            #Minima peak candidate found 
            #look ahead in signal to ensure that this is a peak and not jitter
            if y_axis[index:index+lookahead].min() > mn:
                mintab.append((mnpos, mn))
                dump.append(False)
                #set algorithm to only find maxima now
                mn = -np.Inf
                mx = -np.Inf
    
    
    #Remove the false hit on the first value of the y_axis
    try:
        if dump[0]:
            maxtab.pop(0)
            #print "pop max"
        else:
            mintab.pop(0)
            #print "pop min"
        del dump
    except IndexError:
        #no peaks were found, should the function return empty lists?
        pass
    
    return maxtab, mintab

# %%
def remap(peaks):
    """Reformat coordinates of peaks to properly feed into pyplot"""
    tabs=[]
    for tab in peaks: #mintab and maxtab
        tab=([i[1] for i in tab],[i[0] for i in tab])
        tabs.append(tab)
    return tabs

# %%
### INCOMPLETE
def get_ranges(peaks):
    """Range if there is a min to max or max to min"""
    ranges={}
    both_min_max={}
#     print peaks
    for tab in peaks:
#         print 'tabs'
#         print tab
        peak=tab[0]
        for i in range(len(peak)):
#             print peak
            if ranges.get(i)==None:
                ranges[i]=[peak[i],'just one']
                
            else:
                ranges[i][0]=abs(ranges[i]-peak[i])
                ranges[i][1]='both_min_max'
            return [r[0] for r in ranges.values() if r[1]=="both_min_max"]

# %%
deltas={'acc':.15,'gyro':2500,'magnet':15}

# %%
def plot_peaks(df_x,fig,ax, axes,mylookahead=10, delta=""):
    global deltas
    peak_dict={}
    ranges={}
    for axis in axes:
        peaks=peakdetect(df_x[axis],df_x['t (sec)'], lookahead=mylookahead,delta=delta)
        peaks=remap(peaks)
#         r=get_ranges(peaks)
#         print r
#         ranges[axis]=sum(r)/len(r)
#         print ranges[axis]
        ax.plot(peaks[0][1],peaks[0][0], "o") # Plot dots for local maxima
        ax.plot(peaks[1][1],peaks[1][0], "o") # Plot dots for local minima
        print "%d local min, %d local max found on %s axis" % (len(peaks[1][0]),len(peaks[0][0]),axis)
    return fig, ax

# %%
def plot_sensor(sensor="acc", peaks=True,lookahead=10,user="Morgan",exercise='bicep curls',delta=None):
    #setup a slice of the data frame
    global df, deltas
    df_x=df[df.exerciseType==exercise]
    df_x=df_x[df_x.User==user]
    df_x=df_x[df_x.set_id== int(df_x.set_id.head(1))]
    
    #Make plots
    fig, ax = plt.subplots()
    if sensor=="acc": axes=list(df_x.columns[4:7])
    if sensor=="gyro": axes=list(df_x.columns[7:10])
    if sensor=="magnet": axes=list(df_x.columns[10:13])
        
    for axis in axes:
        ax.plot(df_x['t (sec)'], df_x[axis], label=axis[-1])
    
    if peaks==True:
        if delta==None:
            delta=deltas[sensor]
        plot_peaks(df_x,fig, ax, axes,mylookahead=lookahead, delta=delta)
    ax.legend()
    ax.set_title("10 reps of "+str(df_x.exerciseType.iloc[0])+": sensor="+sensor+", user="+str(df_x.User.iloc[0])+", set_id="+str(df_x.set_id.iloc[0]))
#     return fig, ax

# %%
reps={}
def add_rep_count(set_id,col='acc_y',max_or_min='max',mylookahead=10):
    global reps
    reps[set_id]=0
    #prepare a slice of the dataframe for peak detection
    df_x=df[df.set_id==set_id]
    
    #find peaks
    peaks=peakdetect(df_x[col],df_x['t (sec)'], lookahead=mylookahead)
    if max_or_min=="max": i =0
    elif max_or_min=="min": i =1
    times=[peak[0] for peak in peaks[i]]
    
    #set values
    for time in times:
        reps[set_id]+=1
        rep_index=df_x[df_x['t (sec)']==time].index[0]
        df.rep_count[rep_index]=reps[set_id]
#     print df[df.set_id==set_id]

# %%
def manual_add_rep(i):
    global reps
    reps[set_id]+=1
    df.rep_count[i]=reps[set_id]

# %% [markdown]
# ---
# ## Visualizations and Data Exploration
#
# * *Note: all sets should have exactly 10 reps*
# * *Note: '``lookahead``' is measure of desensitivity to noise: the higher it is the fewer local max and min will be detected*

# %% [markdown]
# #### Bicep Curls

# %%
observations=[]

# %%
#accel
plot_sensor(sensor="acc",lookahead=4,exercise='bicep curls')
# Out:
# 20 local min, 19 local max found on acc_x axis
# 10 local min, 9 local max found on acc_y axis
# 10 local min, 10 local max found on acc_z axis

# %%
observations.append(["x axis on bicep curls has almost 2x as many peaks as other axes","])

# %%
# add_rep_count(set_id=1,max_or_min='min')

# %%
#gyro
plot_sensor(exercise='bicep curls',sensor="gyro", lookahead=7)
# Out:
# 10 local min, 10 local max found on gyro_x axis
# 10 local min, 10 local max found on gyro_y axis
# 10 local min, 10 local max found on gyro_z axis

# %%
#magnetometer
plot_sensor(exercise='bicep curls',sensor="magnet", lookahead=11)
# Out:
# 8 local min, 9 local max found on magnet_x axis
# 9 local min, 10 local max found on magnet_y axis
# 8 local min, 7 local max found on magnet_z axis

# %% [markdown]
# #### Conclusions for Biceps
# * It looks like the **y axis** is most accurate for bicep curl reps
# * The **accelerometer is fastest** by accurately showing 10 reps with ``lookahead=8``

# %% [markdown]
# #### Tricep Curls

# %%
#accelerometer
plot_sensor(sensor="acc",lookahead=9,exercise='tricep',user='Lazar')
# Out:
# 9 local min, 10 local max found on acc_x axis
# 6 local min, 7 local max found on acc_y axis
# 7 local min, 8 local max found on acc_z axis

# %%
#accelerometer
plot_sensor(sensor="acc",lookahead=9,exercise='tricep',user='Morgan')
# Out:
# 9 local min, 10 local max found on acc_x axis
# 8 local min, 7 local max found on acc_y axis
# 9 local min, 10 local max found on acc_z axis

# %%
observations.append('

# %%
plot_sensor(sensor="acc",lookahead=9,exercise='tricep',user='Lazar')
# Out:
# 9 local min, 10 local max found on acc_x axis
# 6 local min, 7 local max found on acc_y axis
# 7 local min, 8 local max found on acc_z axis

# %%
observations.append('y axis acceleromater for tricep curls is very shakey relative to the other axis')

# %%
#gyro
plot_sensor(exercise='tricep',sensor="gyro", lookahead=12)
# Out:
# 9 local min, 10 local max found on gyro_x axis
# 9 local min, 8 local max found on gyro_y axis
# 10 local min, 9 local max found on gyro_z axis

# %%
#magnetometer
plot_sensor(exercise='tricep',sensor="magnet", lookahead=8, user="Lazar")
# Out:
# 10 local min, 9 local max found on magnet_x axis
# 9 local min, 10 local max found on magnet_y axis
# 10 local min, 10 local max found on magnet_z axis

# %%
plot_sensor(exercise='tricep',sensor="magnet", lookahead=8, user="Morgan")
# Out:
# 10 local min, 10 local max found on magnet_x axis
# 9 local min, 10 local max found on magnet_y axis
# 10 local min, 10 local max found on magnet_z axis

# %% [markdown]
# #### Conclusions for Triceps
# * The **Magnetometer** is best for tricep curls: All axis were accurate with peak detection at a very low ``lookahead=8``
#
# #### Other observations
# * Tricep curls magnetometer ranges were all similar, whereas, the bicep curl's Z magnetometer is much smaller than X and Y

# %% [markdown]
# #### Shoulder Press

# %%
plot_sensor(exercise='shoulder',sensor='acc',lookahead=2,delta=.02)
# Out:
# 15 local min, 15 local max found on acc_x axis
# 13 local min, 12 local max found on acc_y axis
# 13 local min, 13 local max found on acc_z axis

# %%
plot_sensor(exercise='shoulder',sensor='gyro',lookahead=10)
# Out:
# 6 local min, 6 local max found on gyro_x axis
# 6 local min, 7 local max found on gyro_y axis
# 9 local min, 8 local max found on gyro_z axis

# %%
plot_sensor(exercise='shoulder',sensor='magnet',lookahead=8)
# Out:
# 8 local min, 8 local max found on magnet_x axis
# 9 local min, 9 local max found on magnet_y axis
# 5 local min, 5 local max found on magnet_z axis

# %% [markdown]
# #### Conclusions for Shoulder
#  The accelerometer and magnetometer show large deltas between respective axes. *Note: good features for classifiers would be:
#
# 1. Average value of an axis
# 2. Difference in of average value of axis between 3 axes (e.g. shoulder seems to have big delta between ave(y) and ave(x) or ave(z)

# %% [markdown]
# ## Future Work
# * Collect more observations about differences in exercises
# * Use above observations to make feature set
# * Improve peak detection algorithm by incorporating range (max-min)
# * Label repitions using peak detection algorithm
# * Segment data into training, test, and holdout
# * Run several supervised learning classifiers (Naive Bayes, SVM) over dataset using aforementioned feature set to automatically classify reps as a certain exercise type.
# * Compare and contrast varios supervised learning methods on accuracy, precision, f-score, and speed.
